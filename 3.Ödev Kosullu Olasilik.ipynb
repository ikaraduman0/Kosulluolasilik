# %% [markdown]
# # Soru - 1

# %% [markdown]
# ###  Bir bisiklet yarışmasına A takımı 5, B takımı ise 6 sporcu ile katılmıştır. Yarışın sonunda  aynı takımdan iki sporcunun yarışı birinci ve ikinci olarak tamamladığı bilindiğine göre bu sporcuların A takımından olma olasılığı nedir?

# %% [markdown]
# # Çözüm

# %% [markdown]
#
#  ![image-2.png](attachment:image-2.png)
#
#  ## Olasılık Değerleri Üzerinden Çözüm
#  11 Yarışmacıdan A'nın birinci gelmesi durumda A'nın ikinci gelme olasılığı;
#  P(A1) = 5/11 <br>
#  P(A2/A1) = 4/10 <br>
#  P(A21) = (5/11) * (4/10) = 4/22
#
#  11 Yarışmacıdan B'nın birinci gelmesi durumda A'nın ikinci gelme olasılığı;
#  P(B1) = 6/11 <br>
#  P(A2/B1) = 5/10 <br>
#  P(A22) = (6/11) * (5/10) = 6/22
#
#  11 Yarışmacıdan A nın ikinci gelme olasılığı;
#  P(A2) = PA21 + PA22 = 4/22 + 6 /22 = 10/22
#
#  Toplam yarışmacılar arasından birinci ve ikinci gelen yarışmacıların A takımından olma olasılığı ise;
#
#  P(ATAKIMI) = (4/22) / (10/22) = 2/5  = %40 tır.

# %%
import math  

# A takımının birinci olması durumda, A takımının ikinci olma olasılığı
A1 = 5/11     
A2A1 = 4/10 
PA21 = (5/11)*(4/10)

# B takımının birinci olması durumda, A takımının ikinci olma olasılığı
B1 = 6/11
A2B1 = 5/10
PA22 = (6/11) * (5/10)

# İkinci gelen yarışmacının A takımından olma olasılığı

PA2= PA21 + PA22

# Birinci ve ikinci olan yarışmacıların aynı takımdan olduğu bilindiğine göre A takımından olma olasılıkları

Kolasilik = PA21 / PA2 
print ("A birinci iken A nın ikinci olma olasılığı = % " ,PA21*100)
print ("B birinci iken A nın ikinci olma olasılığı = % " ,PA22*100)
print ("ikinci yarışmacının A takımından olma olasılığı = % " ,PA2*100)
print ("Yarışmayı A Takımının Hem Birinci Hemde İkinci Olarak Kazanma Olasılığı = % ", Kolasilik*100 ,"dır.")
# Out:
# A birinci iken A nın ikinci olma olasılığı = %  18.181818181818183
# B birinci iken A nın ikinci olma olasılığı = %  27.27272727272727
# ikinci yarışmacının A takımından olma olasılığı = %  45.45454545454545
# Yarışmayı A Takımının Hem Birinci Hemde İkinci Olarak Kazanma Olasılığı = %  40.0 dır.

# %% [markdown]
# # Soru - 2

# %% [markdown]
# ### Her ay 20.000 otomobil lastiği üreten bir fabrikada üretilen lastiklerin her biri üretim sonrası kalite testine tabi tutulmaktadır. Yapılan testlerde %3 pozitif %1 negatif hata payı vardır. Üretilen lastiklerin %2 sinin hatalı olduğu bilindiğine göre rasgele seçilen hatalı bir lastiğin gerçekte de hatalı olma olasılığı nedir?

# %% [markdown]
# # Çözüm
#
# ![image-3.png](attachment:image-3.png)
#
# ## Miktar Bilgisi Üzerinden Çözüm
#
# Fabrikanın ürettiği 20.000 adet lastikten %2 sinin hatalı olduğu bilindiğine göre;
#
# Hatalı = 20.000 * 0,02 = 400 Adet. <br>
# Hatasız = 20.000 * 0,98 = 19.600 Adet. <br>
#
# Hatalı lastiklerde %1 lik negatif hata payı (Hatasız olup hatalı olarak ayrılanlar)
#
# Hatalı olup hatalı olarak ayrılanlar = 396 Adet. <br>
# Hatasız olup hatalı olarak ayrılanlar = 4 Adet. <br>
#
# Hatasız lastiklerde %3 lik Pozitif hata payı (Hatalı olup hatasız olarak ayrılanlar)
#
# Hatasız olup hatasız olarak ayrılanlar = 19.012 Adet. <br>
# Hatalı olup hatasız olarak ayrılanlar = 4 Adet. <br>
#
# Hatalı bir lastiğin gerçekte de hatalı olma olasılığı
#
# Kolailik = 396 / 396 + 588 = 0,4024 = %40

# %%
import math  

# Genel dağılım
Hatali = 20000*0.02
Hatasiz = 20000*0.98

# %1 Negatif Hata Payı
Hli_Hli=Hatali *0.99 
Hli_Hsiz= Hatali * 0.01 

# %3 Pozitif Hata Payı
Hsiz_Hsiz=Hatasiz *0.97 
Hsiz_Hli =Hatasiz *0.03 

Kolasilik= Hli_Hli / (Hli_Hli+Hsiz_Hli)  

print ("Hatalı olarak ayrılan bir lastiğin gerçekte de hatalı olma olasılığı = %", Kolasilik *100 ,"dır.")
# Out:
# Hatalı olarak ayrılan bir lastiğin gerçekte de hatalı olma olasılığı = % 40.243902439024396 dır.
